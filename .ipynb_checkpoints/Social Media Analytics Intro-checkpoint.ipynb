# %%
#Twitter
# Import libraries
import requests
from requests_oauthlib import OAuth1
import json
from urllib.parse import urlparse

#Endpoints
url_rest = "https://api.twitter.com/1.1/search/tweets.json"

#Define parameters
auth_params = {
    'app_key':'2un36FRkkAzcOtoLHZkcTemio', 
    'app_secret':'NaGLsUGsE7nmNBddF9pPpjm3bH8qkNXn3EldRrz8IUTODR8l69',  
    'oauth_token':'106199167-XLotVBELS5wNm3y9iCbLy2hNHowEjRIF3PCjFH8A',
    'oauth_token_secret':'AAFkecfiJqdpu77GDxrdyzewRAllpiF3Q2SYdTv94ygOy' 
}

auth = OAuth1(
    auth_params['app_key'], 
    auth_params['app_secret'], 
    auth_params['oauth_token'], 
    auth_params['oauth_token_secret']
)

query = 'Elecciones AND PRI'

params = {'q' : query, 'count' : 5, 'lang' : 'es'}

results = requests.get(url_rest, params=params, auth=auth)

#print(results.json())

for tweet in results.json()['statuses']:
    print ("created_at: ", tweet['created_at'])
    print ("name: ", tweet['user']['name'])
    print ("location: ", tweet['user']['location'])
    print ("truncated: ", tweet['truncated'])
    print ("text:", tweet['text'])
    print ('\n')
# Out:
# created_at:  Mon Dec 18 17:08:09 +0000 2017
# name:  Abigor
# location:  Donde los caminos se cruzan.
# truncated:  False
# text: Así de puercas van a estar las elecciones del 2018. ¡Gracias, @PRI_Nacional ! https://t.co/Hs0a9JrYW3
#
#
# created_at:  Mon Dec 18 17:05:53 +0000 2017
# name:  Ariel Torres
# location:  Mexico
# truncated:  False
# text: @JoseCardenas1 Como @PRI_Nacional robara elecciones esta ley les dará facultades para reprimir marchas, pus no son weyes
#
#
# created_at:  Mon Dec 18 17:05:15 +0000 2017
# name:  walkingrios
# location:  Monterrey, Nuevo León
# truncated:  False
# text: @Excelsior Y el @PRI_Nacional no ha robado elecciones
#
#
# created_at:  Mon Dec 18 17:00:48 +0000 2017
# name:  😈
# location:
# truncated:  False
# text: RT @Milenio: ¿Indirectas?
#
# Las promesas "IRRESPONSABLES" llevan a la quiebra: @JoseAMeadeK https://t.co/hYKxfT0AFH #Elecciones2018 https://…
#
#
# created_at:  Mon Dec 18 17:00:48 +0000 2017
# name:  juan de dios magaña
# location:
# truncated:  False
# text: RT @Milenio: ¿Indirectas?
#
# Las promesas "IRRESPONSABLES" llevan a la quiebra: @JoseAMeadeK #Elecciones2018
#
# https://t.co/hYKxfT0AFH https:/…

# %%
import requests 
import json

auth_params = {'access_token': 'EAAE0OPeUvUcBAHr0mJC7rvdzlZAJzP27cZAuSTy2ZAN3wjAeCZAnKjiqLpxBgM8M9o1vUpCkTOzsD4lb4kVZAkuoKynQdVONFVYzZCeKvZBEVIIpfLgUhJRY6TpijFZBSD3mwnTqgZA57JhaUsQZBo8LnkS1aPuC7h8RcZD'}

#https://www.facebook.com/vuelaalavida/
#page_url = 'https://graph.facebook.com/v2.8/vuelaalavida/feed' 

page_url = 'https://graph.facebook.com/v2.11/vuelaalavida/posts' 

result = requests.get(page_url, params = auth_params)

data = result.json() 
#print(data)

for element in data['data']: 
    print("created_time: ", element['created_time'])
    print("message: ", element['message'])
    print ('\n')
# Out:
# created_time:  2017-12-16T22:28:07+0000
# message:  🔥🔥 Sigue en oferta 🔥🔥
# 5 días y 4 noches en Mazatlán saliendo de CDMX desde $3,412Pesos/$180 USD.
#
# TODA LA INFO: http://vuelaalavida.com/oferta/paqmazatlan1217j/
# Precio final! Viaje redondo! Opción de pagar a meses!
#
#
# created_time:  2017-12-16T19:50:00+0000
# message:  4 días y 3 noches en La paz saliendo de CDMX o Guadalajara desde $2,563Pesos/$135 USD. ¡¡Vuelo+Hotel!!
# TODA LA INFO:  http://vuelaalavida.com/oferta/paqlapaz1217j/ ‎
#
#
# created_time:  2017-12-16T18:55:01+0000
# message:  🌴😎☀ PURA VIDA ☀😎🌴
# Paquete de 3 noches con vuelo y hotel en Costa Rica desde CDMX desde $4,358Pesos / $227USD redondo! Resto de México desde $4,732Pesos!
#
# TODA LA INFO: http://vuelaalavida.com/oferta/costarica1217p/
# Precio final! Viaje redondo!
#
#
# created_time:  2017-12-16T18:07:15+0000
# message:  ¡¡Súper precio!!
# Vuela a Lima saliendo de CDMX o Guadalajara desde $4,738 pesos/ 247USD ¡De GDL muy poca disponibilidad!
# TODA LA INFO:  http://vuelaalavida.com/oferta/lim1217g/ ‎
#
#
# created_time:  2017-12-16T01:40:46+0000
# message:  🌌✈️🌌¡Viaja y conoce Yellowknife!🌌✈️🌌
# Saliendo de CDMX desde $5,762 Pesos / $301 USD ¡El vuelo es redondo!
# TODA LA INFO: http://vuelaalavida.com/oferta/yzf1217ap/
# ¡Aprovecha! ¡No lo dejes pasar!
#
#
# created_time:  2017-12-16T00:26:00+0000
# message:  4 días en Vancouver saliendo de CDMX o Cancún desde $5,937Pesos/$310USD. ¡¡Vuelos+Hotel!!
# TODA LA INFO: https://vuelaalavida.com/oferta/paqvancouver1217j/
# Precio final, paga a meses.
#
#
# created_time:  2017-12-15T21:50:34+0000
# message:  ¡¡SÚPER BARATO Y SIN PASAR POR EEUU!! 😱😱
# De CDMX a Islandia vía Toronto desde $9,504Pesos/$498 USD.
# TODA LA INFO: https://vuelaalavida.com/oferta/islandia1217j/
# Precio final, vuelo redondo.
#
#
# created_time:  2017-12-15T20:05:00+0000
# message:  😎😎¡Pura vida, Costa Rica!😎😎
# Vuelo redondo a San José, Costa Rica saliendo de CDMX desde $3,651 Pesos / $191 USD
# TODA LA INFO AQUÍ: https://vuelaalavida.com/oferta/sjo1217gf/
#
#
# created_time:  2017-12-15T19:22:19+0000
# message:  🍹😎🌴 SÚPER LUJO EN TAILANDIA 🌴😎🍹
# 6 noches en Phuket con vuelos, hotel de lujo de 5 estrellas y desayunos desde $15,912Pesos / $834USD saliendo de CDMX! TE REGALAMOS EL SEGURO!
#
# TODA LA INFO: https://vuelaalavida.com/oferta/phuket1217p/
# Precio final! Viaje redondo! Opción de pagar a meses!
#
#
# created_time:  2017-12-15T17:40:00+0000
# message:  !!No dejes pasar la oportunidad!!
# 😉😉😉Viaja a Londres saliendo de Los Ángeles desde $6,082Pesos/$318USD vuelo redondo😉😉😉
# TODA LA INFO EN: http://vuelaalavida.com/oferta/londres1217a/
#
#
# created_time:  2017-12-15T16:55:00+0000
# message:  ☀🍹😎 Todo incluido en Cozumel 😎🍹☀
# Paquete de 3 noches a Cozumel desde CDMX, GDL, MTY, León y muchas ciudades más desde $5,556Pesos en habitación doble o $4,508Pesos en habitación familiar!
#
# TODA LA INFO: http://vuelaalavida.com/oferta/coz1217p/
# Precio final! Viaje redondo!
#
#
# created_time:  2017-12-15T15:51:23+0000
# message:  :D ¡No lo dejes pasar! :D
# Vuela de Toronto de CDMX o Cancún desde $4,621 pesos/ 242USD
# 🔥 ¡De CDMX por un poco más aplica para navidad y Año nuevo! 🔥
#
# TODA LA INFO:  http://vuelaalavida.com/oferta/toronto1217g/ ‎
# SIN PASAR LOS EE.UU.! Imp. incluidos! Ida y vuelta! Paga a meses!
#
#
# created_time:  2017-12-15T14:52:15+0000
# message:  🏝️🌞🏝️🌞Vacaciones en Miami🌞🏝️🌞🏝️
# Saliendo de Cancún desde $3,261Pesos/$170USD vuelo redondo y directo
# ¡Hay buena disponibilidad!
# TODA LA INFO: http://vuelaalavida.com/oferta/miami1217a/
#
#
# created_time:  2017-12-15T08:19:44+0000
# message:  ✈🌴🇺🇸 VACACIONES EN MIAMI??? ✈🌴🇺🇸
# Vuela de CDMX directo a Fort Lauderdale desde $3,223 pesos/$168 USD! ¡Recuerda que requieres Visa!
#
# TODA LA INFO: https://vuelaalavida.com/oferta/fortlauderdale1217l/
# Precio final! Viaje redondo!
#
#
# created_time:  2017-12-14T22:55:04+0000
# message:  🏖️🏖️🏖️¡Esta es tu oportunidad! ¡Viaja a Huatulco!🏖️🏖️🏖️
# ¡Paquete de VUELOS + HOTEL! De CDMX a Huatulco 4 días / 3 noches por tan solo $2,582 Pesos / $134 USD ¡Vuelos directos! ¡Equipaje incluido!
# TODA LA INFO: http://vuelaalavida.com/oferta/hux1217ap-2/
# ¡No lo dejes pasar!
#
#
# created_time:  2017-12-14T18:50:00+0000
# message:  ✈🌴🇺🇸 VACACIONES EN FLORIDA??? ✈🌴🇺🇸
# Vuela de CDMX directo a Fort Lauderdale desde $3,223 pesos/$168 USD! ¡Recuerda que requieres Visa!
#
# TODA LA INFO: https://vuelaalavida.com/oferta/fortlauderdale1217l/
# Precio final! Viaje redondo!
#
#
# created_time:  2017-12-14T18:00:00+0000
# message:  🗽🗽Canta como Sinatra a la ciudad que nunca duerme🗽🗽
# Vuelo redondo saliendo de Guadalajara a Nueva York desde $4,681 Pesos / $244 USD
# TODA LA INFO AQUÍ: https://vuelaalavida.com/oferta/gdlnyc1217f/
#
#
# created_time:  2017-12-14T17:00:00+0000
# message:  🇨🇺😍🇨🇺 TODOS A CUBA 🇨🇺😍🇨🇺
# Vuela de Cancún o CDMX directo a La Habana desde $3,045 pesos/ 159USD!
#
# TODA LA INFO: https://vuelaalavida.com/oferta/habana1017g-3/
# Precio final! Viaje redondo!
#
#
# created_time:  2017-12-14T16:15:00+0000
# message:  🦎🍃 PURA VIDA 🦎🍃
# Tour en Costa Rica por tan solo $8,043 pesos/ 420USD ¡Con traslados y hospedaje!
# TODA LA INFO: https://vuelaalavida.com/oferta/tourcr1117g/
#
#
# created_time:  2017-12-14T15:10:01+0000
# message:  ✈️¡Viaja a Glasgow, Manchester o Londres! ✈️ ¡Tú decides!
# Saliendo de Cancún desde $10,885 Pesos / $568 USD ¡Aprovecha! ¡Los vuelos son directos e incluyen equipaje!
# TODA LA INFO: http://vuelaalavida.com/oferta/gla1217ap/
# ¡No lo pienses más!
#
#
# created_time:  2017-12-14T01:15:44+0000
# message:  🤩🤩Vuelo triángulo🤩🤩
# De CDMX a Atenas y regresa de Milán desde $13,646Pesos/$713USD.
# TODA LA INFO: https://vuelaalavida.com/oferta/triangulo1217j/
# Precio final, vuelo redondo.
#
#
# created_time:  2017-12-13T21:07:02+0000
# message:  😍 Maravillas del mundo 😍
# Paquete a Cusco con hospedaje, entrada e incluso tours a Machu Picchu, el Valle Sagrado y más desde $9.399Pesos / $495USD!
# TODA LA INFO: https://vuelaalavida.com/oferta/cusco-tour/
#
#
# created_time:  2017-12-13T18:12:28+0000
# message:  🇺🇸🇺🇸Con esta no puedes pensar en otra cosa que no sea viajar🇺🇸🇺🇸
# Vuelo redondo saliendo de Monterrey a Chicago desde $4,837 Pesos / $252 USD Aplica en Navidad y Año Nuevo.
# TODA LA INFO AQUÍ: http://vuelaalavida.com/oferta/chicago1217f/
#
#
# created_time:  2017-12-13T16:45:00+0000
# message:  😎✈🏔Viaja a Lima, Perú😎✈🏔
# Los vuelos son saliendo de CDMX desde $5,734Pesos/$303 USD redondo y sin escalas!
#
# TODA LA INFO: https://vuelaalavida.com/oferta/lima1217l/
# Precio final! No te lo puedes perder!
#
#
# created_time:  2017-12-13T15:55:00+0000
# message:  🌞🏛️🌞🏛️Aplica en Semana Santa!!🌞🏛️🌞🏛️
# Conoce esta increíble ciudad:
# Viaja a Atenas (Grecia) saliendo de CDMX desde $13,684Pesos/$714USD vuelo redondo!!!
# TODA LA INFO EN:
# http://vuelaalavida.com/oferta/atenas1217a/

# %%
import re, itertools 
import nltk 
from nltk.corpus import stopwords
